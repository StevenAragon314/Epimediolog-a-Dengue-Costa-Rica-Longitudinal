# %% [markdown]
# $$\Delta\%_{\text{suavizado}} = \left( \frac{\text{Casos}_{w} - \text{Casos}_{w-1}}{\text{Casos}_{w-1} + 1} \right) \times 100$$

# %% [markdown]
# $$\Delta \text{ Absoluto} = \text{Casos}_{w} - \text{Casos}_{w-1}$$
#
# Promedio Móvil
